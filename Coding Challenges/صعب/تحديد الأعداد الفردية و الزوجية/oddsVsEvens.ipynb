# %% [markdown]
# # Problem Description

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# قم بكتابة دالة function تستقبل عدد صحيح من نوع integer. تقوم الدالة بجمع الأعداد الفردية والزوجية التي يتكون منها العدد الصحيح، في حال كان مجموع الأعداد الفردية أكبر من مجموع الأعداد الزوجية قم بارجاع القيمة odd ، و في حال كان مجموع الأعداد الزوجية أكبر من مجموع الأعداد الفردية قم بإرجاع even و في حال كان مجموع الأعداد الفردية يساوي مجموع الأعداد الزوجية قم بإرجاع equal
# </div>

# %% [markdown]
# ## Solution

# %%
from typing import List
def oddsVsEvens(num: int) -> str:
    even_total = 0
    odd_total = 0

    for n in [int(n) for n in str(num)]:
        if n % 2 == 0:
            even_total += n
        else:
            odd_total += n

    if even_total > odd_total:
        return 'even'
    elif even_total < odd_total: 
        return 'odd'
    return "equal"

# %%
oddsVsEvens(num = 97428)
# Out:
# 'odd'

# %%
oddsVsEvens(num = 81961)
# Out:
# 'even'

# %%
oddsVsEvens(num = 54870)
# Out:
# 'equal'

# %%
oddsVsEvens(num = 26341)
# Out:
# 'even'

# %% [markdown]
# ### Computational Complexity

# %% [markdown]
# #### Time Complexity: $O(n)$
# #### Space Complexity: $O(n)$
