# %% [markdown]
# # Problem Description

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# قم بكتابة دالة function تستقبل قيميتين نصية تقوم الدالة بمقارنة آخر حرفين من كل قيمة ثم تقوم الدالة بإرجاع النتيجة من نوع boolean بالشكل التالي: true اذا اخر حرفين متشابهين، false اذا كانوا مختلفين.
# </div>

# %% [markdown]
# # Solution

# %%
from typing import List
def compare_two_words(s1: str, s2: str) -> bool:
    return s1[-2:] == s2[-2:]

# %%
compare_two_words(s1 = 'abc', s2 = 'abc')
# Out:
# True

# %%
compare_two_words(s1 = 'abcc', s2 = 'abc')
# Out:
# False

# %% [markdown]
# # Computational Complexity

# %% [markdown]
# ## Time and Space Complexity O(1)
