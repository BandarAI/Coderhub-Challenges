# %% [markdown]
# # Problem Description

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# قم بكتابة دالة function تستقبل مصفوفتين من نوع integer ، وتقوم الـدالة function بطرح العناصر الموجودة في المصفوفة الأولى من العناصر الموجودة في المصفوفة الثانية، ثم تقوم بإرجاع مصفوفة من نوع integer
# </div>

# %% [markdown]
# # Solution

# %%
from typing import List
def sub_arrays(arr1: List[int], arr2: List[int]) -> List[int]:
    return [arr2 - arr1 for arr2, arr1 in zip(arr2, arr1)]

# %%
sub_arrays(arr1 = [2, 4, 88],arr2 = [4, 2, 88])
# Out:
# [2, -2, 0]

# %% [markdown]
# # Computational complexity

# %% [markdown]
# ## Time and Space Complexity O(n)
