# %% [markdown]
# # Problem Description

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# قم بكتابة دالة function تستقبل مصفوفة من نوع string تقوم الدالة function *وتقوم الدالة بإرجاع النتيجة كمصفوفة من نوع string بعد إضافة الرقم 5 على كل عنصر موجود داخل المصفوفة . *في حال كانت المصفوفة فارغة تقوم الدالة بارجاع المصفوفة كما هي بدون إضافة.
# </div>

# %% [markdown]
# # Solution

# %%
from typing import List
def add_five(arr: List[str]) -> List[str]:
    return [element + '5' for element in arr]

# %%
add_five(arr = [])
# Out:
# []

# %%
add_five(arr = ['code', 'c'])
# Out:
# ['code5', 'c5']

# %% [markdown]
# # Computational Complexity

# %% [markdown]
# ## Time & Space Complexity O(n)
