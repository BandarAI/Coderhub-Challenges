# %% [markdown]
# # Problem Description

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# قم بكتابة دالة function تستقبل قيمة نصية من نوع string تقوم الـدالة function بإزالة جميع الرموز مثل ($،!،@،#,.) ماعدا ال ( - ـ ) ثم تقوم الدالة بإرجاع النص string بعد عملية الإزالة
# </div>

# %% [markdown]
# ## Solution

# %%
from typing import List
def removeSpecialCharacters(strParam: str) -> str:
    return "".join(ch for ch in strParam if ch.isalnum() or ch in " _-")

# %%
removeSpecialCharacters(strParam = 'Hi How are you!')
# Out:
# 'Hi How are you'

# %%
removeSpecialCharacters(strParam = 'Are_u_coming?')
# Out:
# 'Are_u_coming'

# %%
removeSpecialCharacters(strParam = 'Solve-the-challenge')
# Out:
# 'Solve-the-challenge'

# %%
removeSpecialCharacters(strParam = 'Nora Rahaf$')
# Out:
# 'Nora Rahaf'

# %% [markdown]
# ### Computational Complexity

# %% [markdown]
# #### Time Complexity $O(n)$
# #### Space Complexity $O(1)$
