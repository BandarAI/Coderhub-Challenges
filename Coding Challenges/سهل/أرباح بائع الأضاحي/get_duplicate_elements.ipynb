# %% [markdown]
# # Problem Description

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# تعطى للبائع قائمتان:
#
#     أسعار الشراء لكل رأس من الأضاحي (بالريالات).
#
#     أسعار البيع المقابلة لكل رأس (بالريالات).
#
# مهمتك هي كتابة دالة تُسمى calculateSacrificeProfit تقوم بما يلي:
#
#     تحسب الربح لكل رأس بضرب (سعر البيع − سعر الشراء).
#
#     تلخص هذه الأرباح لتعيد الربح الإجمالي.
#
# إذا كان هناك ربح سلبي في أحد الرؤوس (أي خسارة)، يتم احتسابه أيضًا.
# </div>

# %% [markdown]
# # Solution

# %%
from typing import List
def calculateSacrificeProfit(buyPrices: List[float], sellPrices: List[float]) -> float:
    return sum([sell - buy for sell, buy in zip(sellPrices, buyPrices)])

# %%
calculateSacrificeProfit(buyPrices = [100, 200], sellPrices = [150, 250])
# Out:
# 100

# %% [markdown]
# # Computational Complexity

# %% [markdown]
# ## Time Complexity O(n)
# ## Space Complexity O(1)
