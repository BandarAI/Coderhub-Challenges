# %% [markdown]
# # Problem Description

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# قم بكتابة دالة function تستقبل متغيرين من نوع integer ، تقوم الدالة ـ function باختيار العملية الرياضية المناسبة التي تؤدي للرقم 24 ، ثم قم بارجاع النتيجة من نوع string حيث توضح نوع العملية الرياضية
# </div>

# %% [markdown]
# # Solution

# %% [markdown]
# ## Method 1 - Modulo Check

# %%
from typing import List
def operation(num1: int, num2: int) -> str:
    if num2 != 0 and num1 / num2 == 24:
        return "divided"
    if num1 * num2 == 24:
        return "multiplied"
    if num1 + num2 == 24:
        return "added"
    if num1 - num2 == 24:
        return "subtracted"
    return "None"

# %%
operation(num1 = 6, num2 = 7)
# Out:
# 'None'

# %%
operation(num1 = 20, num2 = 4)
# Out:
# 'added'

# %%
operation(num1 = 3, num2 = 8)
# Out:
# 'multiplied'

# %%
operation(num1 = 24, num2 = 1)
# Out:
# 'divided'

# %% [markdown]
# # Computational Complexity

# %% [markdown]
# ## Time & Space  Complexity O(1)
