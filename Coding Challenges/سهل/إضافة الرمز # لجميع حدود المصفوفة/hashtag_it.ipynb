# %% [markdown]
# # Problem Description

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# قم بكتابة دالة function تستقبل مصفوفة array من نوع string. تقوم الدالة بإضافة الرمز # إلى جميع عناصر المصفوفة وإرجاع النتيجة كقيمة نصية.
# </div>

# %% [markdown]
# # Solution

# %%
from typing import List
def hashtag_it(my_array: List[str]) -> str:
    return (' '.join([f"#{array}" for array in my_array]))

# %%
hashtag_it(my_array = ['stay_home', 'coronavirus', 'Saudi_Arabia'])
# Out:
# '#stay_home #coronavirus #Saudi_Arabia'

# %% [markdown]
# # Computational Complexity

# %% [markdown]
# ## Time Complexity & Space Complexity: O(n)
